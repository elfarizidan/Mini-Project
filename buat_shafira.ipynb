# %% [markdown]
# <a href="https://colab.research.google.com/github/elfarizidan/Mini-Project/blob/main/buat_shafira.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import sys
import base64
import bz2

def ketik(teks, delay=0.05):
    for huruf in teks:
        sys.stdout.write(huruf)
        sys.stdout.flush()
        time.sleep(delay)
    print()

for i in range(5, 0, -1):
    print(i)
    time.sleep(1)

print()

encoded_string = "..."

decoded_bytes = base64.b64decode(encoded_string)
decompressed_bytes = bz2.decompress(decoded_bytes)
cake_art = decompressed_bytes.decode("utf-8")

print(cake_art)
print()

nama = "Shafira Oryza Sativa"
lahir = 2005
usia = 2026 - lahir

ketik(f"Halo, {nama}", 0.07)
ketik(f"Selamat ulang tahun yang ke-{usia}", 0.05)

time.sleep(2)

ketik("Semoga panjang umur,", 0.05)
ketik("sehat selalu,", 0.05)
ketik("diberi kelancaran dalam setiap langkah,", 0.05)
ketik("dan semua impianmu tercapai satu per satu.", 0.05)
ketik("Aamiin", 0.08)
